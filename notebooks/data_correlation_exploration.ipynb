# %% [markdown]
# # Preliminary Data Exploration

# %% [markdown]
# ## Data Cleanup
#
# Data is not terrible; although a few columns that should be numbers are strings.
# EW_CAPABILITY and Intel Confidence also have a few NA's.

# %% [markdown]
# ### Explore data cleanliness

# %%
import pandas as pd
import sys

data_directory = "../Data/unh_hackathon_prompt_2_data.json"
sys.path.append("../UNH-Hackathon-2026-Group-3/")


def load_predictive_warfighting_data(file_path: str = "unh_hackathon_prompt_2_data.json") -> pd.DataFrame:
    """Load data from a CSV file into a pandas DataFrame."""
    return pd.read_json(file_path)

dirty_df = load_predictive_warfighting_data(data_directory)

# print data types of each column
print(dirty_df.dtypes)
# Out:
# Threat Type                         str
# enemy_unit_count                  int64
# Enemy.Capability.Index            int64
# ThreatEscalationHours             int64
# friendlyUnitCount                 int64
# LCS_COUNT                         int64
# Aircraft Count                    int64
# cyber_defense_teams               int64
# Patriot.Batteries                 int64
# ISR_AssetCount                    int64
# satellite coverage score        float64
# JointForceIntegration             int64
# EW_Capability                       str
# Supply Chain Resilience         float64
# PriorEngagements                  int64
# force_readiness_score             int64
# Intel Confidence                    str
# ResponseTime_hrs                  int64
# logistics_delay_hours             int64
# CMD_COORD_SCORE                   int64
# roe_complexity_score              int64
# Operational Budget (MUSD)         int64
# BudgetUtilization_pct             int64
# Weather_Severity                  int64
# Theater Distance KM             float64
# Season                              str
# response_success                    str
# Financial_Loss_MUSD               int64
# actual_days_to_stabilization    float64
# dtype: object

# %% [markdown]
# ### Clean the data

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    """Clean the DataFrame by converting data types."""

    # Convert the string "NULL" to pd.NA
    df = df.replace("NULL", pd.NA)
    df = df.replace("N/A", pd.NA)

    for numeric_string_column in [
        "Enemy.Capability.Index",
        "EW_Capability",
        "Intel Confidence",

    ]:
        df[numeric_string_column] = pd.to_numeric(df[numeric_string_column])

    for boolean_string_column in [
        "response_success"
    ]:
        df[boolean_string_column] = df[boolean_string_column].map({"Yes": 1, "No": 0, "1": 1, "0": 0})

    return df

df = clean_data(dirty_df)
df.head()
# Out:
#   Threat Type  enemy_unit_count  Enemy.Capability.Index  \
# 0     Missile                25                       8
# 1     Missile                 3                       2
# 2         Air                 7                       3
# 3       Cyber                31                       7
# 4      Hybrid                14                       5
#
#    ThreatEscalationHours  friendlyUnitCount  LCS_COUNT  Aircraft Count  \
# 0                     34                 21          0               0
# 1                      8                 45          0               0
# 2                     48                 45          0               5
# 3                     70                 57          0               0
# 4                     27                 57          0               0
#
#    cyber_defense_teams  Patriot.Batteries  ISR_AssetCount  ...  \
# 0                    0                  4              12  ...
# 1                    0                  4               4  ...
# 2                    0                  0              14  ...
# 3                    7                  0               5  ...
# 4                    0                  0              10  ...
#
#    CMD_COORD_SCORE  roe_complexity_score  Operational Budget (MUSD)  \
# 0                7                     3                         98
# 1                9                     5                        189
# 2                9                     1                         92
# 3               10                     3                        314
# 4                6                     4                        290
#
#    BudgetUtilization_pct  Weather_Severity  Theater Distance KM  Season  \
# 0                     84                 3               5164.8  Winter
# 1                     97                 1               7149.7    Fall
# 2                     88                 0               6706.5  Winter
# 3                     86                 9               1851.9    Fall
# 4                     84                 4                983.7  Spring
#
#    response_success  Financial_Loss_MUSD  actual_days_to_stabilization
# 0                 1                  388                          10.1
# 1                 1                  244                           2.0
# 2                 1                  280                           2.0
# 3                 1                  330                           5.3
# 4                 1                  240                          11.0
#
# [5 rows x 29 columns]

# %%
for column in df.columns:
    if df.dtypes[column] == "str":
        print(f"Values: {df[column].drop_duplicates()}")
    else: 
        print(f"Name: {column}, dtype: {df.dtypes[column]}, min: {df[column].min()}, max: {df[column].max()}")
# Out:
# Values: 0       Missile
# 2           Air
# 3         Cyber
# 4        Hybrid
# 7         Naval
# 14          AIR
# 35        CYBER
# 39       Hybrid
# 43          Msl
# 79        naval
# 119       Cyber
# 239         AIR
# 279         Air
# 299       naval
# 319     Missile
# Name: Threat Type, dtype: str
# Name: enemy_unit_count, dtype: int64, min: 1, max: 50
# Name: Enemy.Capability.Index, dtype: int64, min: 1, max: 10
# Name: ThreatEscalationHours, dtype: int64, min: 1, max: 72
# Name: friendlyUnitCount, dtype: int64, min: 5, max: 60
# Name: LCS_COUNT, dtype: int64, min: 0, max: 8
# Name: Aircraft Count, dtype: int64, min: 0, max: 24
# Name: cyber_defense_teams, dtype: int64, min: 0, max: 12
# Name: Patriot.Batteries, dtype: int64, min: 0, max: 6
# Name: ISR_AssetCount, dtype: int64, min: 0, max: 15
# Name: satellite coverage score, dtype: float64, min: 0.2, max: 1.0
# Name: JointForceIntegration, dtype: int64, min: 1, max: 10
# Name: EW_Capability, dtype: float64, min: 0.0, max: 10.0
# Name: Supply Chain Resilience, dtype: float64, min: 0.4, max: 1.0
# Name: PriorEngagements, dtype: int64, min: 0, max: 25
# Name: force_readiness_score, dtype: int64, min: 40, max: 100
# Name: Intel Confidence, dtype: float64, min: 0.3, max: 1.0
# Name: ResponseTime_hrs, dtype: int64, min: 1, max: 48
# Name: logistics_delay_hours, dtype: int64, min: 0, max: 24
# Name: CMD_COORD_SCORE, dtype: int64, min: 1, max: 10
# Name: roe_complexity_score, dtype: int64, min: 1, max: 5
# Name: Operational Budget (MUSD), dtype: int64, min: 50, max: 500
# Name: BudgetUtilization_pct, dtype: int64, min: 60, max: 100
# Name: Weather_Severity, dtype: int64, min: 0, max: 10
# Name: Theater Distance KM, dtype: float64, min: 504.9, max: 9997.0
# Values: 0        Winter
# 1          Fall
# 4        Spring
# 7        Summer
# 24       spring
# 34        Fall
# 69      Winter
# 104     Summer
# 111      Autumn
# 119      SUMMER
# 139     Spring
# 174     spring
# 559     Autumn
# 1889    SUMMER
# Name: Season, dtype: str
# Name: response_success, dtype: int64, min: 0, max: 1
# Name: Financial_Loss_MUSD, dtype: int64, min: 63, max: 658
# Name: actual_days_to_stabilization, dtype: float64, min: 2.0, max: 28.2

# %%
OUTCOME_COLUMNS = ["response_success", "actual_days_to_stabilization", "Financial_Loss_MUSD"]
LOW_RANGE_SCORE_COLUMNS = [
    # "Weather_Severity", 
    # "CMD_COORD_SCORE", 
    "roe_complexity_score", 
    # "EW_Capability", 
    # "JointForceIntegration", 
    # "Enemy.Capability.Index"
]

# %% [markdown]
# ### Missing values check
#
# EW_Capability and Intel Confidence have a few null values.
#
# TODO LATER: explore if there are any patterns in the data for these null columns.

# %%
print(df.isna().sum())
# Out:
# Threat Type                      0
# enemy_unit_count                 0
# Enemy.Capability.Index           0
# ThreatEscalationHours            0
# friendlyUnitCount                0
# LCS_COUNT                        0
# Aircraft Count                   0
# cyber_defense_teams              0
# Patriot.Batteries                0
# ISR_AssetCount                   0
# satellite coverage score         0
# JointForceIntegration            0
# EW_Capability                   30
# Supply Chain Resilience          0
# PriorEngagements                 0
# force_readiness_score            0
# Intel Confidence                25
# ResponseTime_hrs                 0
# logistics_delay_hours            0
# CMD_COORD_SCORE                  0
# roe_complexity_score             0
# Operational Budget (MUSD)        0
# BudgetUtilization_pct            0
# Weather_Severity                 0
# Theater Distance KM              0
# Season                           0
# response_success                 0
# Financial_Loss_MUSD              0
# actual_days_to_stabilization     0
# dtype: int64

# %% [markdown]
# ## Train / Test Split

# %% [markdown]
# Before we dive further, it's important to reserve some of the data as a test set. That way our evaluation down the road will still be unbiased even if we engineer a model's features on the basis of what we find in our analysis.

# %%
TRAIN_FRACTION=0.8
train_df = df.sample(frac=TRAIN_FRACTION, random_state=42)
test_df = df.drop(train_df.index)

# %% [markdown]
# ## Correlation analysis

# %% [markdown]
# ### Compute correlation of fields

# %%
correlation_matrix = train_df.select_dtypes(exclude=[pd.StringDtype]).corr()
correlation_matrix
# Out:
# /tmp/ipykernel_4245/443309417.py:1: UserWarning: Instantiating StringDtype without any arguments.Pass a StringDtype instance to silence this warning.
#   correlation_matrix = train_df.select_dtypes(exclude=[pd.StringDtype]).corr()
#                               enemy_unit_count  Enemy.Capability.Index  \
# enemy_unit_count                      1.000000                0.030340
# Enemy.Capability.Index                0.030340                1.000000
# ThreatEscalationHours                 0.011560                0.020750
# friendlyUnitCount                     0.011785                0.033608
# LCS_COUNT                            -0.004453               -0.018010
# Aircraft Count                        0.008104                0.002674
# cyber_defense_teams                   0.021492               -0.011624
# Patriot.Batteries                    -0.007721                0.029226
# ISR_AssetCount                        0.013723                0.041913
# satellite coverage score             -0.003528                0.008861
# JointForceIntegration                 0.038649                0.013066
# EW_Capability                         0.015309                0.014123
# Supply Chain Resilience              -0.017962                0.013543
# PriorEngagements                      0.009790                0.022300
# force_readiness_score                -0.021503               -0.030672
# Intel Confidence                     -0.008968                0.005016
# ResponseTime_hrs                      0.001768               -0.004662
# logistics_delay_hours                 0.019362               -0.025509
# CMD_COORD_SCORE                       0.002887                0.014421
# roe_complexity_score                 -0.018665                0.031363
# Operational Budget (MUSD)             0.022749               -0.009266
# BudgetUtilization_pct                 0.033747               -0.007993
# Weather_Severity                      0.003610               -0.027946
# Theater Distance KM                  -0.038888                0.006450
# response_success                     -0.103322               -0.391682
# Financial_Loss_MUSD                   0.390822                0.405702
# actual_days_to_stabilization          0.024088                0.100299
#
#                               ThreatEscalationHours  friendlyUnitCount  \
# enemy_unit_count                           0.011560           0.011785
# Enemy.Capability.Index                     0.020750           0.033608
# ThreatEscalationHours                      1.000000           0.013678
# friendlyUnitCount                          0.013678           1.000000
# LCS_COUNT                                  0.011420           0.018623
# Aircraft Count                            -0.027830           0.032474
# cyber_defense_teams                        0.021191           0.001568
# Patriot.Batteries                         -0.014160          -0.033848
# ISR_AssetCount                             0.014895           0.023332
# satellite coverage score                   0.025494          -0.024906
# JointForceIntegration                     -0.008629           0.008584
# EW_Capability                              0.003499          -0.045448
# Supply Chain Resilience                    0.021609           0.004282
# PriorEngagements                           0.019485           0.012811
# force_readiness_score                     -0.006433          -0.008693
# Intel Confidence                          -0.040849          -0.000479
# ResponseTime_hrs                          -0.032307          -0.002048
# logistics_delay_hours                      0.023187          -0.025897
# CMD_COORD_SCORE                            0.014367           0.024786
# roe_complexity_score                      -0.006469           0.001394
# Operational Budget (MUSD)                  0.002116           0.031364
# BudgetUtilization_pct                     -0.006228          -0.020997
# Weather_Severity                           0.033396           0.033644
# Theater Distance KM                        0.015685           0.009566
# response_success                          -0.156243          -0.009125
# Financial_Loss_MUSD                        0.062626           0.038218
# actual_days_to_stabilization               0.056890          -0.036710
#
#                               LCS_COUNT  Aircraft Count  cyber_defense_teams  \
# enemy_unit_count              -0.004453        0.008104             0.021492
# Enemy.Capability.Index        -0.018010        0.002674            -0.011624
# ThreatEscalationHours          0.011420       -0.027830             0.021191
# friendlyUnitCount              0.018623        0.032474             0.001568
# LCS_COUNT                      1.000000       -0.237511            -0.178070
# Aircraft Count                -0.237511        1.000000            -0.184183
# cyber_defense_teams           -0.178070       -0.184183             1.000000
# Patriot.Batteries             -0.156583       -0.161958            -0.121425
# ISR_AssetCount                 0.001421       -0.002721            -0.004376
# satellite coverage score      -0.017933        0.010719            -0.018432
# JointForceIntegration          0.016850       -0.004028             0.003454
# EW_Capability                  0.003849       -0.019786             0.014581
# Supply Chain Resilience       -0.010637        0.012344             0.000360
# PriorEngagements              -0.003906        0.031613             0.023369
# force_readiness_score         -0.001904        0.020387            -0.002116
# Intel Confidence              -0.042210       -0.001295            -0.030648
# ResponseTime_hrs              -0.019166        0.007265             0.020737
# logistics_delay_hours         -0.014973        0.025457            -0.001148
# CMD_COORD_SCORE                0.012527        0.004125            -0.006524
# roe_complexity_score          -0.001524       -0.015177            -0.010246
# Operational Budget (MUSD)     -0.010264       -0.014136            -0.006408
# BudgetUtilization_pct         -0.045905        0.030205             0.009487
# Weather_Severity              -0.003306        0.005311             0.006313
# Theater Distance KM           -0.007491       -0.010342             0.009857
# response_success               0.059739        0.128918             0.053688
# Financial_Loss_MUSD            0.159619        0.406336            -0.056428
# actual_days_to_stabilization  -0.002811       -0.006617            -0.297426
#
#                               Patriot.Batteries  ISR_AssetCount  \
# enemy_unit_count                      -0.007721        0.013723
# Enemy.Capability.Index                 0.029226        0.041913
# ThreatEscalationHours                 -0.014160        0.014895
# friendlyUnitCount                     -0.033848        0.023332
# LCS_COUNT                             -0.156583        0.001421
# Aircraft Count                        -0.161958       -0.002721
# cyber_defense_teams                   -0.121425       -0.004376
# Patriot.Batteries                      1.000000       -0.014935
# ISR_AssetCount                        -0.014935        1.000000
# satellite coverage score               0.005270       -0.027374
# JointForceIntegration                 -0.006594        0.025132
# EW_Capability                          0.027743       -0.015802
# Supply Chain Resilience               -0.004903        0.007751
# PriorEngagements                      -0.023234        0.000244
# force_readiness_score                 -0.012850       -0.007446
# Intel Confidence                       0.017581       -0.006074
# ResponseTime_hrs                       0.038216        0.018907
# logistics_delay_hours                 -0.007149        0.005629
# CMD_COORD_SCORE                        0.007736        0.000202
# roe_complexity_score                   0.023753       -0.025682
# Operational Budget (MUSD)              0.022594        0.008952
# BudgetUtilization_pct                  0.002018       -0.015684
# Weather_Severity                       0.008652        0.034262
# Theater Distance KM                    0.000656       -0.002378
# response_success                       0.030549        0.082713
# Financial_Loss_MUSD                   -0.016751        0.307288
# actual_days_to_stabilization          -0.107021       -0.187827
#
#                               satellite coverage score  ...  \
# enemy_unit_count                             -0.003528  ...
# Enemy.Capability.Index                        0.008861  ...
# ThreatEscalationHours                         0.025494  ...
# friendlyUnitCount                            -0.024906  ...
# LCS_COUNT                                    -0.017933  ...
# Aircraft Count                                0.010719  ...
# cyber_defense_teams                          -0.018432  ...
# Patriot.Batteries                             0.005270  ...
# ISR_AssetCount                               -0.027374  ...
# satellite coverage score                      1.000000  ...
# JointForceIntegration                         0.002054  ...
# EW_Capability                                 0.027361  ...
# Supply Chain Resilience                       0.008671  ...
# PriorEngagements                              0.017321  ...
# force_readiness_score                         0.005884  ...
# Intel Confidence                              0.038660  ...
# ResponseTime_hrs                              0.004647  ...
# logistics_delay_hours                        -0.012169  ...
# CMD_COORD_SCORE                              -0.026096  ...
# roe_complexity_score                         -0.007501  ...
# Operational Budget (MUSD)                    -0.006245  ...
# BudgetUtilization_pct                        -0.006042  ...
# Weather_Severity                             -0.024907  ...
# Theater Distance KM                           0.019262  ...
# response_success                              0.063970  ...
# Financial_Loss_MUSD                          -0.038023  ...
# actual_days_to_stabilization                 -0.081514  ...
#
#                               logistics_delay_hours  CMD_COORD_SCORE  \
# enemy_unit_count                           0.019362         0.002887
# Enemy.Capability.Index                    -0.025509         0.014421
# ThreatEscalationHours                      0.023187         0.014367
# friendlyUnitCount                         -0.025897         0.024786
# LCS_COUNT                                 -0.014973         0.012527
# Aircraft Count                             0.025457         0.004125
# cyber_defense_teams                       -0.001148        -0.006524
# Patriot.Batteries                         -0.007149         0.007736
# ISR_AssetCount                             0.005629         0.000202
# satellite coverage score                  -0.012169        -0.026096
# JointForceIntegration                     -0.032746        -0.002914
# EW_Capability                              0.017392         0.008211
# Supply Chain Resilience                    0.003843        -0.023349
# PriorEngagements                          -0.016408         0.006441
# force_readiness_score                     -0.027118        -0.009067
# Intel Confidence                           0.007166        -0.057734
# ResponseTime_hrs                           0.013496         0.007539
# logistics_delay_hours                      1.000000         0.034972
# CMD_COORD_SCORE                            0.034972         1.000000
# roe_complexity_score                       0.004714        -0.000288
# Operational Budget (MUSD)                  0.028897         0.007364
# BudgetUtilization_pct                     -0.017197        -0.012480
# Weather_Severity                           0.018574        -0.007607
# Theater Distance KM                       -0.021571         0.012776
# response_success                          -0.072551        -0.053163
# Financial_Loss_MUSD                        0.281575         0.047691
# actual_days_to_stabilization               0.644830        -0.250505
#
#                               roe_complexity_score  Operational Budget (MUSD)  \
# enemy_unit_count                         -0.018665                   0.022749
# Enemy.Capability.Index                    0.031363                  -0.009266
# ThreatEscalationHours                    -0.006469                   0.002116
# friendlyUnitCount                         0.001394                   0.031364
# LCS_COUNT                                -0.001524                  -0.010264
# Aircraft Count                           -0.015177                  -0.014136
# cyber_defense_teams                      -0.010246                  -0.006408
# Patriot.Batteries                         0.023753                   0.022594
# ISR_AssetCount                           -0.025682                   0.008952
# satellite coverage score                 -0.007501                  -0.006245
# JointForceIntegration                     0.001780                  -0.025501
# EW_Capability                            -0.016005                  -0.000593
# Supply Chain Resilience                  -0.019263                   0.034621
# PriorEngagements                         -0.015045                   0.010983
# force_readiness_score                     0.024144                   0.036907
# Intel Confidence                          0.005797                  -0.023859
# ResponseTime_hrs                          0.003928                   0.034483
# logistics_delay_hours                     0.004714                   0.028897
# CMD_COORD_SCORE                          -0.000288                   0.007364
# roe_complexity_score                      1.000000                   0.017317
# Operational Budget (MUSD)                 0.017317                   1.000000
# BudgetUtilization_pct                     0.020330                   0.033240
# Weather_Severity                         -0.003386                  -0.024755
# Theater Distance KM                      -0.012706                   0.006529
# response_success                         -0.082565                  -0.021595
# Financial_Loss_MUSD                       0.018201                   0.025581
# actual_days_to_stabilization              0.034277                   0.024216
#
#                               BudgetUtilization_pct  Weather_Severity  \
# enemy_unit_count                           0.033747          0.003610
# Enemy.Capability.Index                    -0.007993         -0.027946
# ThreatEscalationHours                     -0.006228          0.033396
# friendlyUnitCount                         -0.020997          0.033644
# LCS_COUNT                                 -0.045905         -0.003306
# Aircraft Count                             0.030205          0.005311
# cyber_defense_teams                        0.009487          0.006313
# Patriot.Batteries                          0.002018          0.008652
# ISR_AssetCount                            -0.015684          0.034262
# satellite coverage score                  -0.006042         -0.024907
# JointForceIntegration                     -0.014510          0.010479
# EW_Capability                              0.042717         -0.003022
# Supply Chain Resilience                   -0.019318         -0.032158
# PriorEngagements                          -0.011451         -0.018850
# force_readiness_score                     -0.019676          0.026579
# Intel Confidence                          -0.005316          0.003296
# ResponseTime_hrs                          -0.013384          0.005317
# logistics_delay_hours                     -0.017197          0.018574
# CMD_COORD_SCORE                           -0.012480         -0.007607
# roe_complexity_score                       0.020330         -0.003386
# Operational Budget (MUSD)                  0.033240         -0.024755
# BudgetUtilization_pct                      1.000000          0.021580
# Weather_Severity                           0.021580          1.000000
# Theater Distance KM                       -0.027184          0.020185
# response_success                          -0.011255         -0.118362
# Financial_Loss_MUSD                       -0.002569          0.068464
# actual_days_to_stabilization              -0.001716          0.045458
#
#                               Theater Distance KM  response_success  \
# enemy_unit_count                        -0.038888         -0.103322
# Enemy.Capability.Index                   0.006450         -0.391682
# ThreatEscalationHours                    0.015685         -0.156243
# friendlyUnitCount                        0.009566         -0.009125
# LCS_COUNT                               -0.007491          0.059739
# Aircraft Count                          -0.010342          0.128918
# cyber_defense_teams                      0.009857          0.053688
# Patriot.Batteries                        0.000656          0.030549
# ISR_AssetCount                          -0.002378          0.082713
# satellite coverage score                 0.019262          0.063970
# JointForceIntegration                    0.018653          0.132068
# EW_Capability                           -0.017832          0.063730
# Supply Chain Resilience                 -0.023636          0.059319
# PriorEngagements                        -0.000596          0.096900
# force_readiness_score                   -0.047037          0.146735
# Intel Confidence                        -0.000103          0.104530
# ResponseTime_hrs                        -0.018776         -0.014023
# logistics_delay_hours                   -0.021571         -0.072551
# CMD_COORD_SCORE                          0.012776         -0.053163
# roe_complexity_score                    -0.012706         -0.082565
# Operational Budget (MUSD)                0.006529         -0.021595
# BudgetUtilization_pct                   -0.027184         -0.011255
# Weather_Severity                         0.020185         -0.118362
# Theater Distance KM                      1.000000         -0.089165
# response_success                        -0.089165          1.000000
# Financial_Loss_MUSD                      0.159918         -0.424596
# actual_days_to_stabilization             0.003568         -0.464321
#
#                               Financial_Loss_MUSD  \
# enemy_unit_count                         0.390822
# Enemy.Capability.Index                   0.405702
# ThreatEscalationHours                    0.062626
# friendlyUnitCount                        0.038218
# LCS_COUNT                                0.159619
# Aircraft Count                           0.406336
# cyber_defense_teams                     -0.056428
# Patriot.Batteries                       -0.016751
# ISR_AssetCount                           0.307288
# satellite coverage score                -0.038023
# JointForceIntegration                   -0.025445
# EW_Capability                           -0.018676
# Supply Chain Resilience                 -0.058018
# PriorEngagements                        -0.015053
# force_readiness_score                   -0.074524
# Intel Confidence                        -0.072345
# ResponseTime_hrs                         0.333746
# logistics_delay_hours                    0.281575
# CMD_COORD_SCORE                          0.047691
# roe_complexity_score                     0.018201
# Operational Budget (MUSD)                0.025581
# BudgetUtilization_pct                   -0.002569
# Weather_Severity                         0.068464
# Theater Distance KM                      0.159918
# response_success                        -0.424596
# Financial_Loss_MUSD                      1.000000
# actual_days_to_stabilization             0.243614
#
#                               actual_days_to_stabilization
# enemy_unit_count                                  0.024088
# Enemy.Capability.Index                            0.100299
# ThreatEscalationHours                             0.056890
# friendlyUnitCount                                -0.036710
# LCS_COUNT                                        -0.002811
# Aircraft Count                                   -0.006617
# cyber_defense_teams                              -0.297426
# Patriot.Batteries                                -0.107021
# ISR_AssetCount                                   -0.187827
# satellite coverage score                         -0.081514
# JointForceIntegration                            -0.255295
# EW_Capability                                     0.041550
# Supply Chain Resilience                          -0.009920
# PriorEngagements                                 -0.246009
# force_readiness_score                            -0.066003
# Intel Confidence                                 -0.018302
# ResponseTime_hrs                                 -0.002681
# logistics_delay_hours                             0.644830
# CMD_COORD_SCORE                                  -0.250505
# roe_complexity_score                              0.034277
# Operational Budget (MUSD)                         0.024216
# BudgetUtilization_pct                            -0.001716
# Weather_Severity                                  0.045458
# Theater Distance KM                               0.003568
# response_success                                 -0.464321
# Financial_Loss_MUSD                               0.243614
# actual_days_to_stabilization                      1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# ### Most correlated fields

# %% [markdown]
# If two fields have very high correlation (either positive or negative), it may be a good idea to drop one of them from our analysis as they are redundant.

# %%
sorted_by_most_correlated = correlation_matrix.reset_index().melt(
    id_vars=['index'],
).sort_values(by="value", key=abs, ascending=False)
sorted_by_most_correlated = sorted_by_most_correlated[sorted_by_most_correlated["index"] != sorted_by_most_correlated["variable"]]
sorted_by_most_correlated.head(30)
# Out:
#                             index                      variable     value
# 719         logistics_delay_hours  actual_days_to_stabilization  0.644830
# 485  actual_days_to_stabilization         logistics_delay_hours  0.644830
# 674  actual_days_to_stabilization              response_success -0.464321
# 726              response_success  actual_days_to_stabilization -0.464321
# 699              response_success           Financial_Loss_MUSD -0.424596
# 673           Financial_Loss_MUSD              response_success -0.424596
# 680                Aircraft Count           Financial_Loss_MUSD  0.406336
# 160           Financial_Loss_MUSD                Aircraft Count  0.406336
# 676        Enemy.Capability.Index           Financial_Loss_MUSD  0.405702
# 52            Financial_Loss_MUSD        Enemy.Capability.Index  0.405702
# 649        Enemy.Capability.Index              response_success -0.391682
# 51               response_success        Enemy.Capability.Index -0.391682
# 25            Financial_Loss_MUSD              enemy_unit_count  0.390822
# 675              enemy_unit_count           Financial_Loss_MUSD  0.390822
# 457           Financial_Loss_MUSD              ResponseTime_hrs  0.333746
# 691              ResponseTime_hrs           Financial_Loss_MUSD  0.333746
# 241           Financial_Loss_MUSD                ISR_AssetCount  0.307288
# 683                ISR_AssetCount           Financial_Loss_MUSD  0.307288
# 188  actual_days_to_stabilization           cyber_defense_teams -0.297426
# 708           cyber_defense_teams  actual_days_to_stabilization -0.297426
# 692         logistics_delay_hours           Financial_Loss_MUSD  0.281575
# 484           Financial_Loss_MUSD         logistics_delay_hours  0.281575
# 712         JointForceIntegration  actual_days_to_stabilization -0.255295
# 296  actual_days_to_stabilization         JointForceIntegration -0.255295
# 512  actual_days_to_stabilization               CMD_COORD_SCORE -0.250505
# 720               CMD_COORD_SCORE  actual_days_to_stabilization -0.250505
# 715              PriorEngagements  actual_days_to_stabilization -0.246009
# 377  actual_days_to_stabilization              PriorEngagements -0.246009
# 701  actual_days_to_stabilization           Financial_Loss_MUSD  0.243614
# 727           Financial_Loss_MUSD  actual_days_to_stabilization  0.243614

# %% [markdown]
# ### Most correlated fields to variety of "outcome" fields

# %% [markdown]
# #### Response success

# %%
sorted_by_most_correlated[sorted_by_most_correlated["index"] == "response_success"]
# Out:
#                 index                      variable     value
# 726  response_success  actual_days_to_stabilization -0.464321
# 699  response_success           Financial_Loss_MUSD -0.424596
# 51   response_success        Enemy.Capability.Index -0.391682
# 78   response_success         ThreatEscalationHours -0.156243
# 402  response_success         force_readiness_score  0.146735
# 294  response_success         JointForceIntegration  0.132068
# 159  response_success                Aircraft Count  0.128918
# 618  response_success              Weather_Severity -0.118362
# 429  response_success              Intel Confidence  0.104530
# 24   response_success              enemy_unit_count -0.103322
# 375  response_success              PriorEngagements  0.096900
# 645  response_success           Theater Distance KM -0.089165
# 240  response_success                ISR_AssetCount  0.082713
# 537  response_success          roe_complexity_score -0.082565
# 483  response_success         logistics_delay_hours -0.072551
# 267  response_success      satellite coverage score  0.063970
# 321  response_success                 EW_Capability  0.063730
# 132  response_success                     LCS_COUNT  0.059739
# 348  response_success       Supply Chain Resilience  0.059319
# 186  response_success           cyber_defense_teams  0.053688
# 510  response_success               CMD_COORD_SCORE -0.053163
# 213  response_success             Patriot.Batteries  0.030549
# 564  response_success     Operational Budget (MUSD) -0.021595
# 456  response_success              ResponseTime_hrs -0.014023
# 591  response_success         BudgetUtilization_pct -0.011255
# 105  response_success             friendlyUnitCount -0.009125

# %% [markdown]
# #### Financial Loss

# %%
sorted_by_most_correlated[sorted_by_most_correlated["index"] == "Financial_Loss_MUSD"]
# Out:
#                    index                      variable     value
# 673  Financial_Loss_MUSD              response_success -0.424596
# 160  Financial_Loss_MUSD                Aircraft Count  0.406336
# 52   Financial_Loss_MUSD        Enemy.Capability.Index  0.405702
# 25   Financial_Loss_MUSD              enemy_unit_count  0.390822
# 457  Financial_Loss_MUSD              ResponseTime_hrs  0.333746
# 241  Financial_Loss_MUSD                ISR_AssetCount  0.307288
# 484  Financial_Loss_MUSD         logistics_delay_hours  0.281575
# 727  Financial_Loss_MUSD  actual_days_to_stabilization  0.243614
# 646  Financial_Loss_MUSD           Theater Distance KM  0.159918
# 133  Financial_Loss_MUSD                     LCS_COUNT  0.159619
# 403  Financial_Loss_MUSD         force_readiness_score -0.074524
# 430  Financial_Loss_MUSD              Intel Confidence -0.072345
# 619  Financial_Loss_MUSD              Weather_Severity  0.068464
# 79   Financial_Loss_MUSD         ThreatEscalationHours  0.062626
# 349  Financial_Loss_MUSD       Supply Chain Resilience -0.058018
# 187  Financial_Loss_MUSD           cyber_defense_teams -0.056428
# 511  Financial_Loss_MUSD               CMD_COORD_SCORE  0.047691
# 106  Financial_Loss_MUSD             friendlyUnitCount  0.038218
# 268  Financial_Loss_MUSD      satellite coverage score -0.038023
# 565  Financial_Loss_MUSD     Operational Budget (MUSD)  0.025581
# 295  Financial_Loss_MUSD         JointForceIntegration -0.025445
# 322  Financial_Loss_MUSD                 EW_Capability -0.018676
# 538  Financial_Loss_MUSD          roe_complexity_score  0.018201
# 214  Financial_Loss_MUSD             Patriot.Batteries -0.016751
# 376  Financial_Loss_MUSD              PriorEngagements -0.015053
# 592  Financial_Loss_MUSD         BudgetUtilization_pct -0.002569

# %% [markdown]
# #### Actual Days to Stabilization

# %%
sorted_by_most_correlated[sorted_by_most_correlated["index"] == "actual_days_to_stabilization"]
# Out:
#                             index                   variable     value
# 485  actual_days_to_stabilization      logistics_delay_hours  0.644830
# 674  actual_days_to_stabilization           response_success -0.464321
# 188  actual_days_to_stabilization        cyber_defense_teams -0.297426
# 296  actual_days_to_stabilization      JointForceIntegration -0.255295
# 512  actual_days_to_stabilization            CMD_COORD_SCORE -0.250505
# 377  actual_days_to_stabilization           PriorEngagements -0.246009
# 701  actual_days_to_stabilization        Financial_Loss_MUSD  0.243614
# 242  actual_days_to_stabilization             ISR_AssetCount -0.187827
# 215  actual_days_to_stabilization          Patriot.Batteries -0.107021
# 53   actual_days_to_stabilization     Enemy.Capability.Index  0.100299
# 269  actual_days_to_stabilization   satellite coverage score -0.081514
# 404  actual_days_to_stabilization      force_readiness_score -0.066003
# 80   actual_days_to_stabilization      ThreatEscalationHours  0.056890
# 620  actual_days_to_stabilization           Weather_Severity  0.045458
# 323  actual_days_to_stabilization              EW_Capability  0.041550
# 107  actual_days_to_stabilization          friendlyUnitCount -0.036710
# 539  actual_days_to_stabilization       roe_complexity_score  0.034277
# 566  actual_days_to_stabilization  Operational Budget (MUSD)  0.024216
# 26   actual_days_to_stabilization           enemy_unit_count  0.024088
# 431  actual_days_to_stabilization           Intel Confidence -0.018302
# 350  actual_days_to_stabilization    Supply Chain Resilience -0.009920
# 161  actual_days_to_stabilization             Aircraft Count -0.006617
# 647  actual_days_to_stabilization        Theater Distance KM  0.003568
# 134  actual_days_to_stabilization                  LCS_COUNT -0.002811
# 458  actual_days_to_stabilization           ResponseTime_hrs -0.002681
# 593  actual_days_to_stabilization      BudgetUtilization_pct -0.001716

# %% [markdown]
# ## PCA Analysis

# %%
import numpy as np
from collections.abc import Mapping, Sequence
from matplotlib import pyplot as plt

class CovarianceArrayStore:
    col_name_to_ind: Mapping[str, int]
    normalized_values_array: np.ndarray
    covariance_array: np.ndarray
    def get(self, a: str, b: str) -> float:
        return self.covariance_array[self.col_name_to_ind[a], self.col_name_to_ind[b]].item()

def to_covariance_array_store(df: pd.DataFrame) -> CovarianceArrayStore:
    df = df.select_dtypes(include=['number'])
    result = CovarianceArrayStore()
    result.col_name_to_ind = {}
    for i, column in enumerate(df.columns):
        result.col_name_to_ind[column] = i

    U = df.dropna().to_numpy()
    result.normalized_values_array = X = (U - np.mean(U, axis=0)) / np.std(U, axis=0)
    result.covariance_array = np.matmul(X.T, X) / (X.shape[0] - 1)
    return result

class PcaResult:
    columns: pd.Index
    compressed_dataset: np.ndarray
    principal_components: np.ndarray
    principal_component_scores: np.ndarray
    def principal_component_dataframe(self) -> pd.DataFrame:
        principal_component_score_column = self.principal_component_scores.reshape(1,-1)
        principal_component_score_column_norm = principal_component_score_column / np.sum(principal_component_score_column)
        return pd.DataFrame(
            data=np.concat((self.principal_components, principal_component_score_column, principal_component_score_column_norm), axis=0).T,
            columns=list(self.columns) + ["score"] + ["variance_explained"]
        )

def pca(df: pd.DataFrame, dim: int) -> PcaResult:
    covariance_tensor_store = to_covariance_array_store(df)
    w, v = np.linalg.eig(covariance_tensor_store.covariance_array)
    sort_inds_desc = w.argsort()[::-1]
    eigenvectors = v[:, sort_inds_desc]
    eigenvalues = w[sort_inds_desc]
    dataset_projection_onto_eigenvectors = np.matmul(covariance_tensor_store.normalized_values_array, eigenvectors[:,:dim])

    result = PcaResult()
    result.columns = df.select_dtypes(include=["number"]).columns
    result.principal_components = eigenvectors
    result.principal_component_scores = eigenvalues
    result.compressed_dataset = dataset_projection_onto_eigenvectors
    return result

# %%
# A lot of the dataset is simply "scores", and the scores are on different scales.
# Normalizing all data means how "extreme" a feature's scaling is 
numeric_df = train_df.select_dtypes(include=["number"])

pca_result = pca(numeric_df, dim=2)
pca_result.principal_component_dataframe().head(26)
# Out:
#     enemy_unit_count  Enemy.Capability.Index  ThreatEscalationHours  \
# 0           0.178549                0.278890               0.096395
# 1           0.241792                0.231094              -0.003964
# 2          -0.030030                0.280795               0.227900
# 3          -0.009977               -0.150427               0.022659
# 4           0.200415               -0.090662              -0.114933
# 5           0.142363               -0.272805               0.126505
# 6           0.223179                0.142764               0.082924
# 7           0.142322               -0.228893              -0.228359
# 8           0.320564                0.126768              -0.097682
# 9           0.055264                0.154221               0.064800
# 10         -0.057852               -0.171926               0.474674
# 11         -0.094733               -0.015552              -0.230967
# 12          0.294394               -0.095031              -0.157730
# 13          0.086123                0.112923               0.136131
# 14          0.020431               -0.097296               0.202722
# 15          0.302826               -0.204727               0.290642
# 16          0.193875                0.007259              -0.184729
# 17         -0.052297               -0.027496               0.099226
# 18         -0.427254                0.031433              -0.078472
# 19          0.108774               -0.054650              -0.228277
# 20          0.302593               -0.355008               0.265427
# 21          0.181909               -0.055078              -0.399489
# 22         -0.010283               -0.104013               0.169605
# 23         -0.142978                0.196264               0.103588
# 24         -0.207319               -0.510773              -0.129779
# 25          0.013288                0.008946              -0.000967
#
#     friendlyUnitCount  LCS_COUNT  Aircraft Count  cyber_defense_teams  \
# 0            0.012205   0.029758        0.116892            -0.139857
# 1            0.120137   0.003972        0.239295             0.119206
# 2            0.020637   0.089034       -0.562946             0.245878
# 3            0.100435   0.767367       -0.230665            -0.242679
# 4           -0.256908   0.085280       -0.388491             0.103152
# 5            0.017407  -0.130784       -0.049849             0.659241
# 6           -0.236698   0.051121       -0.087727             0.116459
# 7           -0.023611  -0.011303        0.034690            -0.141736
# 8           -0.100955   0.211569        0.081852            -0.066260
# 9            0.167344   0.055504       -0.154002             0.117940
# 10          -0.042064   0.103470        0.039303            -0.143249
# 11          -0.320393   0.084212       -0.057222             0.165240
# 12           0.292061   0.030433       -0.178558             0.049109
# 13          -0.013228  -0.090431        0.014416            -0.064223
# 14           0.098962  -0.024591        0.048836             0.016310
# 15          -0.246481  -0.038588       -0.020718            -0.140717
# 16           0.469314   0.023706       -0.018388            -0.001963
# 17           0.430222  -0.051254       -0.037361             0.069783
# 18           0.104361   0.096564       -0.045419            -0.031588
# 19          -0.170837   0.095278       -0.091885             0.034434
# 20           0.175161   0.035315        0.039452            -0.029316
# 21          -0.049352  -0.031666        0.034214             0.007390
# 22          -0.268460  -0.025879        0.134893            -0.046055
# 23          -0.046651   0.410580        0.301305             0.381023
# 24           0.023955   0.166626        0.176764             0.205067
# 25           0.004185   0.071940        0.080421             0.258767
#
#     Patriot.Batteries  ISR_AssetCount  satellite coverage score  ...  \
# 0           -0.046085        0.030307                 -0.058426  ...
# 1           -0.020193        0.358198                  0.016488  ...
# 2            0.142857       -0.100006                 -0.057796  ...
# 3           -0.304333        0.175270                 -0.092638  ...
# 4            0.425459        0.147615                  0.002001  ...
# 5           -0.465230        0.052829                 -0.194615  ...
# 6           -0.099318        0.027261                  0.383062  ...
# 7            0.166535        0.110172                 -0.191903  ...
# 8           -0.275668       -0.285388                 -0.010784  ...
# 9           -0.037050        0.226433                 -0.087117  ...
# 10           0.029869        0.013723                  0.366945  ...
# 11          -0.110948       -0.162523                  0.190613  ...
# 12           0.130858       -0.037981                 -0.083796  ...
# 13           0.176392       -0.003068                 -0.223972  ...
# 14           0.010227       -0.262383                  0.169133  ...
# 15           0.207464       -0.076696                  0.095333  ...
# 16           0.000197       -0.549066                  0.144589  ...
# 17           0.012923        0.276171                  0.528208  ...
# 18           0.017439        0.039016                 -0.092912  ...
# 19          -0.093338       -0.025941                  0.259503  ...
# 20           0.102881       -0.048919                 -0.224534  ...
# 21           0.048467        0.098367                  0.213282  ...
# 22          -0.219884       -0.057087                 -0.081481  ...
# 23           0.355661       -0.308158                 -0.052069  ...
# 24           0.199691        0.030030                  0.075090  ...
# 25           0.134602        0.134115                  0.050994  ...
#
#     roe_complexity_score  Operational Budget (MUSD)  BudgetUtilization_pct  \
# 0               0.044690                   0.024647               0.002613
# 1              -0.035386                  -0.005440              -0.012260
# 2               0.114857                  -0.033089              -0.020285
# 3              -0.090926                  -0.046774              -0.245804
# 4               0.016240                   0.251709               0.054800
# 5              -0.156706                  -0.001753               0.087176
# 6              -0.266529                  -0.318276              -0.004208
# 7              -0.020401                  -0.277478               0.272284
# 8               0.219809                   0.056722               0.461108
# 9               0.249044                  -0.070891               0.033008
# 10             -0.142230                   0.155735               0.238868
# 11              0.141249                  -0.322457              -0.245317
# 12             -0.050674                   0.336411              -0.006621
# 13             -0.268356                  -0.430821              -0.307104
# 14              0.582880                  -0.114845              -0.097153
# 15             -0.146369                  -0.029823               0.017868
# 16             -0.358986                  -0.006967              -0.125804
# 17              0.080049                  -0.039381              -0.042820
# 18             -0.005832                  -0.176426               0.320220
# 19             -0.003331                  -0.092037               0.230611
# 20              0.294672                  -0.315445              -0.030226
# 21              0.253471                   0.052447              -0.318924
# 22              0.045649                   0.395729              -0.378262
# 23              0.003447                   0.069417              -0.007802
# 24             -0.064963                  -0.014759              -0.001375
# 25              0.004655                   0.001649               0.005964
#
#     Weather_Severity  Theater Distance KM  response_success  \
# 0           0.079642             0.070327         -0.442975
# 1           0.020604             0.094619          0.029538
# 2           0.065194             0.135049         -0.421316
# 3          -0.012436             0.001537          0.121466
# 4          -0.089087            -0.196312          0.118488
# 5           0.134584            -0.043886          0.038539
# 6          -0.142742             0.104485          0.042576
# 7           0.402263             0.054195          0.043447
# 8          -0.236877            -0.401481         -0.049643
# 9           0.402804            -0.236535         -0.028408
# 10          0.380682             0.226110          0.016990
# 11         -0.054194             0.174432         -0.016568
# 12         -0.078917             0.146827          0.048427
# 13          0.080205            -0.456317         -0.007967
# 14          0.116668            -0.034023          0.055175
# 15          0.029100            -0.210245         -0.017188
# 16          0.214957            -0.022743         -0.064912
# 17         -0.198111            -0.380552          0.050331
# 18          0.143922            -0.183266         -0.005022
# 19          0.245536            -0.055172         -0.061497
# 20         -0.199019             0.213232          0.069013
# 21          0.323946             0.005855          0.003491
# 22          0.207162            -0.283924         -0.088158
# 23          0.098443            -0.050380          0.291819
# 24         -0.153706            -0.135052         -0.581772
# 25          0.003571             0.005720          0.244636
#
#     Financial_Loss_MUSD  actual_days_to_stabilization     score  \
# 0              0.493535                      0.470514  2.479977
# 1              0.421708                     -0.468729  1.693806
# 2             -0.135711                     -0.125490  1.391064
# 3              0.050803                      0.032862  1.244401
# 4              0.082845                     -0.001357  1.168921
# 5             -0.005125                      0.032580  1.157035
# 6              0.036709                      0.022347  1.113126
# 7              0.012473                     -0.016929  1.095979
# 8             -0.006483                     -0.033771  1.085591
# 9              0.011485                      0.013536  1.055649
# 10             0.016300                     -0.039416  1.041114
# 11             0.073890                     -0.018402  1.032832
# 12             0.009468                      0.006893  1.012514
# 13            -0.031318                     -0.011997  1.004824
# 14            -0.011865                      0.011207  0.983320
# 15            -0.011311                      0.001955  0.976368
# 16            -0.030507                      0.029554  0.965197
# 17            -0.015098                     -0.002610  0.949680
# 18            -0.016456                      0.012227  0.931061
# 19             0.008264                     -0.040390  0.905415
# 20             0.050369                     -0.027165  0.889147
# 21            -0.012894                     -0.007860  0.866822
# 22            -0.027452                     -0.048241  0.861202
# 23             0.206218                     -0.133793  0.636199
# 24             0.196199                     -0.039067  0.401016
# 25            -0.024592                      0.715173  0.064538
#
#     variance_explained
# 0             0.091812
# 1             0.062707
# 2             0.051499
# 3             0.046069
# 4             0.043275
# 5             0.042835
# 6             0.041209
# 7             0.040575
# 8             0.040190
# 9             0.039081
# 10            0.038543
# 11            0.038237
# 12            0.037485
# 13            0.037200
# 14            0.036404
# 15            0.036146
# 16            0.035733
# 17            0.035158
# 18            0.034469
# 19            0.033520
# 20            0.032917
# 21            0.032091
# 22            0.031883
# 23            0.023553
# 24            0.014846
# 25            0.002389
#
# [26 rows x 29 columns]

# %%
def nth_component_columns_ordered_by_magnitude(pca: PcaResult, n: int) -> pd.Series:
    df = pca.principal_component_dataframe().drop(columns="score")
    return df.iloc[n].sort_values(key=abs, ascending=False)

# %%
num_interested_principal_components = 4
for n in range(num_interested_principal_components):
    score = pca_result.principal_component_dataframe().at[n, "score"]
    variance_explained = pca_result.principal_component_dataframe().at[n, "variance_explained"]
    print(f"{n+1}th principal component, columns ordered by mangitude (score={score}, variance explained={variance_explained})")
    print(nth_component_columns_ordered_by_magnitude(pca_result, n))
# Out:
# 1th principal component, columns ordered by mangitude (score=2.4799773439994315, variance explained=0.09181196043938432)
# Financial_Loss_MUSD             0.493535
# actual_days_to_stabilization    0.470514
# response_success               -0.442975
# logistics_delay_hours           0.327515
# Enemy.Capability.Index          0.278890
# enemy_unit_count                0.178549
# cyber_defense_teams            -0.139857
# JointForceIntegration          -0.124631
# Aircraft Count                  0.116892
# ResponseTime_hrs                0.112234
# PriorEngagements               -0.110751
# force_readiness_score          -0.102039
# ThreatEscalationHours           0.096395
# variance_explained              0.091812
# Weather_Severity                0.079642
# Theater Distance KM             0.070327
# Intel Confidence               -0.068632
# satellite coverage score       -0.058426
# Patriot.Batteries              -0.046085
# roe_complexity_score            0.044690
# Supply Chain Resilience        -0.040546
# ISR_AssetCount                  0.030307
# LCS_COUNT                       0.029758
# CMD_COORD_SCORE                -0.027531
# Operational Budget (MUSD)       0.024647
# friendlyUnitCount               0.012205
# EW_Capability                  -0.007837
# BudgetUtilization_pct           0.002613
# Name: 0, dtype: float64
# 2th principal component, columns ordered by mangitude (score=1.693805827269792, variance explained=0.06270687673077727)
# actual_days_to_stabilization   -0.468729
# Financial_Loss_MUSD             0.421708
# ISR_AssetCount                  0.358198
# logistics_delay_hours          -0.272804
# enemy_unit_count                0.241792
# Aircraft Count                  0.239295
# Enemy.Capability.Index          0.231094
# ResponseTime_hrs                0.225495
# JointForceIntegration           0.220653
# CMD_COORD_SCORE                 0.204283
# PriorEngagements                0.197496
# friendlyUnitCount               0.120137
# cyber_defense_teams             0.119206
# Theater Distance KM             0.094619
# Intel Confidence               -0.070225
# EW_Capability                  -0.063708
# variance_explained              0.062707
# roe_complexity_score           -0.035386
# response_success                0.029538
# Weather_Severity                0.020604
# Patriot.Batteries              -0.020193
# satellite coverage score        0.016488
# Supply Chain Resilience        -0.012597
# BudgetUtilization_pct          -0.012260
# force_readiness_score          -0.011884
# Operational Budget (MUSD)      -0.005440
# LCS_COUNT                       0.003972
# ThreatEscalationHours          -0.003964
# Name: 1, dtype: float64
# 3th principal component, columns ordered by mangitude (score=1.3910640052668126, variance explained=0.05149898394403936)
# Aircraft Count                 -0.562946
# response_success               -0.421316
# Enemy.Capability.Index          0.280795
# logistics_delay_hours          -0.270736
# cyber_defense_teams             0.245878
# ThreatEscalationHours           0.227900
# force_readiness_score          -0.191780
# CMD_COORD_SCORE                 0.169313
# Intel Confidence               -0.162596
# ResponseTime_hrs               -0.145909
# Patriot.Batteries               0.142857
# Financial_Loss_MUSD            -0.135711
# Theater Distance KM             0.135049
# actual_days_to_stabilization   -0.125490
# roe_complexity_score            0.114857
# ISR_AssetCount                 -0.100006
# LCS_COUNT                       0.089034
# Supply Chain Resilience        -0.087929
# Weather_Severity                0.065194
# PriorEngagements               -0.058249
# satellite coverage score       -0.057796
# variance_explained              0.051499
# EW_Capability                  -0.045140
# Operational Budget (MUSD)      -0.033089
# enemy_unit_count               -0.030030
# friendlyUnitCount               0.020637
# BudgetUtilization_pct          -0.020285
# JointForceIntegration           0.018804
# Name: 2, dtype: float64
# 4th principal component, columns ordered by mangitude (score=1.2444008809299085, variance explained=0.0460693258860263)
# LCS_COUNT                       0.767367
# Patriot.Batteries              -0.304333
# BudgetUtilization_pct          -0.245804
# cyber_defense_teams            -0.242679
# Aircraft Count                 -0.230665
# ISR_AssetCount                  0.175270
# Enemy.Capability.Index         -0.150427
# JointForceIntegration           0.135903
# Intel Confidence               -0.123102
# response_success                0.121466
# friendlyUnitCount               0.100435
# satellite coverage score       -0.092638
# roe_complexity_score           -0.090926
# EW_Capability                  -0.067401
# logistics_delay_hours           0.053572
# Financial_Loss_MUSD             0.050803
# Operational Budget (MUSD)      -0.046774
# variance_explained              0.046069
# CMD_COORD_SCORE                 0.034376
# actual_days_to_stabilization    0.032862
# ResponseTime_hrs               -0.030972
# PriorEngagements               -0.025625
# ThreatEscalationHours           0.022659
# Supply Chain Resilience         0.017142
# force_readiness_score           0.015011
# Weather_Severity               -0.012436
# enemy_unit_count               -0.009977
# Theater Distance KM             0.001537
# Name: 3, dtype: float64

# %%
plt.scatter(x=pca_result.compressed_dataset[:,0], y=pca_result.compressed_dataset[:,1])

# %% [markdown]
# ## Feature Combination Analysis with PCA + Logistic Regression
#
# Iterating through all possible feature combinations to find the best predictors for response_success.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

# Get all numeric features (excluding outcome variables)
all_numeric_features = [col for col in train_df.select_dtypes(include=['number']).columns 
                        if col not in OUTCOME_COLUMNS]

print(f"Total numeric features available: {len(all_numeric_features)}")
print(f"Features: {all_numeric_features}")

# Target variable
target = 'response_success'

# Store results
results = []

# Iterate through all possible feature combinations (from 2 to all features)
# Starting from 2 features to make PCA meaningful
for num_features in range(len(all_numeric_features)-1, len(all_numeric_features) + 1):
    print(f"\nEvaluating combinations with {num_features} features...")
    
    for feature_combo in combinations(all_numeric_features, num_features):
        try:
            # Select features for this combination
            feature_list = list(feature_combo)
            
            # Prepare training data
            X_train = train_df[feature_list].dropna()
            y_train = train_df.loc[X_train.index, target]
            
            # Prepare test data[]
            X_test = test_df[feature_list].dropna()
            y_test = test_df.loc[X_test.index, target]
            
            # Skip if not enough samples
            if len(X_train) < 10 or len(X_test) < 5:
                continue
            
            # Apply PCA (reduce to min(n_features-1, n_samples-1) components)
            n_components = min(len(feature_list), len(X_train) - 1, 10)
            pca_result = pca(X_train, dim=n_components)
            
            # Transform test data using the same PCA
            covariance_store = to_covariance_array_store(X_train)
            X_test_normalized = (X_test.to_numpy() - np.mean(covariance_store.normalized_values_array, axis=0)) / (np.std(covariance_store.normalized_values_array, axis=0) + 1e-8)
            
            # Get eigenvectors for projection
            w, v = np.linalg.eig(covariance_store.covariance_array)
            sort_inds_desc = w.argsort()[::-1]
            eigenvectors = v[:, sort_inds_desc]
            X_test_pca = np.matmul(X_test_normalized, eigenvectors[:, :n_components])
            
            # Train logistic regression on PCA components
            log_reg = LogisticRegression(max_iter=1000, random_state=42)
            log_reg.fit(pca_result.compressed_dataset, y_train)
            
            # Predict on test set
            y_pred = log_reg.predict(X_test_pca)
            
            # Calculate accuracy
            accuracy = accuracy_score(y_test, y_pred)
            
            # Store results
            results.append({
                'features': feature_list,
                'num_features': len(feature_list),
                'n_components': n_components,
                'accuracy': accuracy,
                'train_samples': len(X_train),
                'test_samples': len(X_test)
            })
            
        except Exception as e:
            # Skip combinations that cause errors
            continue

print(f"\nTotal combinations evaluated: {len(results)}")
# Out:
# Total numeric features available: 24
# Features: ['enemy_unit_count', 'Enemy.Capability.Index', 'ThreatEscalationHours', 'friendlyUnitCount', 'LCS_COUNT', 'Aircraft Count', 'cyber_defense_teams', 'Patriot.Batteries', 'ISR_AssetCount', 'satellite coverage score', 'JointForceIntegration', 'EW_Capability', 'Supply Chain Resilience', 'PriorEngagements', 'force_readiness_score', 'Intel Confidence', 'ResponseTime_hrs', 'logistics_delay_hours', 'CMD_COORD_SCORE', 'roe_complexity_score', 'Operational Budget (MUSD)', 'BudgetUtilization_pct', 'Weather_Severity', 'Theater Distance KM']
#
# Evaluating combinations with 23 features...
#
# Evaluating combinations with 24 features...
#
# Total combinations evaluated: 25

# %%
# Convert results to DataFrame and sort by accuracy
results_df = pd.DataFrame(results)
results_df = results_df.sort_values('accuracy', ascending=False).reset_index(drop=True)

# Display top 20 combinations
print("="*80)
print("TOP 20 FEATURE COMBINATIONS BY ACCURACY")
print("="*80)
for idx, row in results_df.head(20).iterrows():
    print(f"\nRank {idx + 1}: Accuracy = {row['accuracy']:.4f}")
    print(f"  Features ({row['num_features']}): {', '.join(row['features'])}")
    print(f"  PCA Components: {row['n_components']}")
    print(f"  Train/Test samples: {row['train_samples']}/{row['test_samples']}")

# Show the complete sorted DataFrame
results_df
# Out:
# ================================================================================
# TOP 20 FEATURE COMBINATIONS BY ACCURACY
# ================================================================================
#
# Rank 1: Accuracy = 0.2698
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 2: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 3: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 4: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 5: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 6: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 7: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 8: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 9: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 10: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 11: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 12: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 13: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 14: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 15: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 16: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 17: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 18: Accuracy = 0.1417
#   Features (23): Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 19: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#
# Rank 20: Accuracy = 0.1417
#   Features (23): enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
#   PCA Components: 10
#   Train/Test samples: 2352/593
#                                              features  num_features  \
# 0   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 1   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 2   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 3   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 4   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 5   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 6   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 7   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 8   [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 9   [enemy_unit_count, Enemy.Capability.Index, fri...            23
# 10  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 11  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 12  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 13  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 14  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 15  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 16  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 17  [Enemy.Capability.Index, ThreatEscalationHours...            23
# 18  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 19  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 20  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 21  [enemy_unit_count, Enemy.Capability.Index, Thr...            24
# 22  [enemy_unit_count, ThreatEscalationHours, frie...            23
# 23  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
# 24  [enemy_unit_count, Enemy.Capability.Index, Thr...            23
#
#     n_components  accuracy  train_samples  test_samples
# 0             10  0.269815           2352           593
# 1             10  0.141653           2352           593
# 2             10  0.141653           2352           593
# 3             10  0.141653           2352           593
# 4             10  0.141653           2352           593
# 5             10  0.141653           2352           593
# 6             10  0.141653           2352           593
# 7             10  0.141653           2352           593
# 8             10  0.141653           2352           593
# 9             10  0.141653           2352           593
# 10            10  0.141653           2352           593
# 11            10  0.141653           2352           593
# 12            10  0.141653           2352           593
# 13            10  0.141653           2352           593
# 14            10  0.141653           2352           593
# 15            10  0.141653           2352           593
# 16            10  0.141653           2352           593
# 17            10  0.141653           2352           593
# 18            10  0.141653           2352           593
# 19            10  0.141653           2352           593
# 20            10  0.141653           2352           593
# 21            10  0.141653           2352           593
# 22            10  0.141653           2352           593
# 23            10  0.141176           2380           595
# 24            10  0.140468           2372           598

# %%
# Visualize accuracy distribution by number of features
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Plot 1: Accuracy by number of features
results_df.boxplot(column='accuracy', by='num_features', ax=axes[0])
axes[0].set_title('Accuracy Distribution by Number of Features')
axes[0].set_xlabel('Number of Features')
axes[0].set_ylabel('Accuracy')
axes[0].get_figure().suptitle('')

# Plot 2: Top 15 combinations
top_15 = results_df.head(15).copy()
top_15['feature_label'] = top_15.apply(lambda x: f"{x['num_features']} features", axis=1)
axes[1].barh(range(len(top_15)), top_15['accuracy'])
axes[1].set_yticks(range(len(top_15)))
axes[1].set_yticklabels([f"Rank {i+1} ({row['num_features']} feat)" for i, row in top_15.iterrows()])
axes[1].set_xlabel('Accuracy')
axes[1].set_title('Top 15 Feature Combinations')
axes[1].invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Summary statistics
print("="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"\nBest Accuracy: {results_df['accuracy'].max():.4f}")
print(f"Worst Accuracy: {results_df['accuracy'].min():.4f}")
print(f"Mean Accuracy: {results_df['accuracy'].mean():.4f}")
print(f"Median Accuracy: {results_df['accuracy'].median():.4f}")

print("\n" + "="*80)
print("BEST ACCURACY BY NUMBER OF FEATURES")
print("="*80)
for num_feat in sorted(results_df['num_features'].unique()):
    subset = results_df[results_df['num_features'] == num_feat]
    best_row = subset.iloc[0]
    print(f"\n{num_feat} features: {best_row['accuracy']:.4f}")
    print(f"  Best combination: {', '.join(best_row['features'])}")
# Out:
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
#
# Best Accuracy: 0.2698
# Worst Accuracy: 0.1405
# Mean Accuracy: 0.1467
# Median Accuracy: 0.1417
#
# ================================================================================
# BEST ACCURACY BY NUMBER OF FEATURES
# ================================================================================
#
# 23 features: 0.2698
#   Best combination: enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity
#
# 24 features: 0.1417
#   Best combination: enemy_unit_count, Enemy.Capability.Index, ThreatEscalationHours, friendlyUnitCount, LCS_COUNT, Aircraft Count, cyber_defense_teams, Patriot.Batteries, ISR_AssetCount, satellite coverage score, JointForceIntegration, EW_Capability, Supply Chain Resilience, PriorEngagements, force_readiness_score, Intel Confidence, ResponseTime_hrs, logistics_delay_hours, CMD_COORD_SCORE, roe_complexity_score, Operational Budget (MUSD), BudgetUtilization_pct, Weather_Severity, Theater Distance KM
